# %% [markdown]
# # Oscilloscope Capture
#
# The following data was captured from what I belive to be the top left service port of the dishwasher motherboard
#
# ![Low Voltage Ports](images/low-voltage-ports.jpg)
